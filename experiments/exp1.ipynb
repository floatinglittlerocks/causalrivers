# %%
import pandas as pd
from IPython.display import display, HTML
from assembly_tools import format_table, extract_raw_performance, build_exp1
from hydra import initialize, compose
import numpy as np

# %% [markdown]
# ### Assembly of experimental results 1

# %%
# We conduced a large HP search to determine which HP configurations are optimal for a certain method and dataset. 
# You can un the same HP searches by using the benchmarking script in the causal discovery zoo folder. 
# Check the readme for details. You can also reproduce the all numbers by running the selected HP combo in the same way with the benchmark script .

# %% [markdown]
# # Styling of the table

# %%
build_exp1(scoring="Individual AUROC", null_name="Null AUROC")
# Out:
# /home/stein/project_repos/causal_rivers_core/experiments/assembly_tools.py:130: DtypeWarning: Columns (22,24,25,30,54,55,58,59,61,62,63,64,66,67,75,76,77,81,82,85,86,87,88,89,90,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(cfg.data_path + "exp1/cached.csv", index_col=0)
# renaming.. resolution_value
# renaming.. method_hps.max_lag
# renaming.. method_hps.cp_architecture
# renaming.. ds_name
# renaming.. normalize
# renaming.. window_data_month_value
# renaming.. window_data_year_value
# \begin{tabular}{lrrrrrrrrrrr}
#  & close_3 & close_5 & root_cause_3 & root_cause_5 & 1_random_3 & 1_random_5 & confounder_3 & confounder_5 & random_3 & random_5 & disjoint_10 \\
# Null model &.50 &.50 &.50 &.50 &.50 &.50 &.50 &.50 &.50 &.50 &.50 \\
# RP &.80 &.76 &.76 &.70 &.74 &.73 &.62 &.66 &.79 &.75 &.75 \\
# RP+N &.72 &.62 & {\cellcolor[HTML]{B8F2BE}}.81 & {\cellcolor[HTML]{A5CFA9}}.77 &.71 &.65 &.58 &.58 &.72 &.64 &.65 \\
# RP+B &.78 &.71 &.61 &.53 &.81 &.71 &.61 &.62 &.76 &.68 &.58 \\
# CC &.68 &.63 &.70 &.67 &.64 &.66 &.65 &.59 &.71 &.71 &.66 \\
# CC+C &.69 &.64 &.72 &.70 &.69 &.67 &.64 &.60 &.71 &.67 &.75 \\
# RPCC &.70 &.66 &.70 &.65 &.68 &.68 &.63 &.60 &.72 &.71 &.71 \\
# RPCC+N &.68 &.60 &.73 &.70 &.67 &.64 &.62 &.57 &.69 &.64 &.66 \\
# RPCC+B &.68 &.63 &.60 &.55 &.72 &.66 &.63 &.58 &.69 &.65 &.57 \\
# RPCC+C &.71 &.66 &.71 &.68 &.71 &.67 &.65 &.61 &.71 &.67 &.75 \\
# VAR & {\cellcolor[HTML]{B8F2BE}}.81 & {\cellcolor[HTML]{A5CFA9}}.81 & {\cellcolor[HTML]{A5CFA9}}.79 &.75 &.80 & {\cellcolor[HTML]{A5CFA9}}.79 & {\cellcolor[HTML]{B8F2BE}}.71 & {\cellcolor[HTML]{B8F2BE}}.72 & {\cellcolor[HTML]{B8F2BE}}.82 & {\cellcolor[HTML]{B8F2BE}}.80 & {\cellcolor[HTML]{A5CFA9}}.82 \\
# Varlingam &.79 &.77 &.77 & {\cellcolor[HTML]{B8F2BE}}.77 & {\cellcolor[HTML]{B8F2BE}}.84 &.79 & {\cellcolor[HTML]{A5CFA9}}.68 &.70 &.79 &.75 & {\cellcolor[HTML]{B8F2BE}}.83 \\
# dynotears &.50 &.50 &.50 &.56 &.52 &.61 &.53 &.53 &.50 &.61 &.61 \\
# PCMCI &.64 &.62 &.70 &.74 & {\cellcolor[HTML]{A5CFA9}}.83 &.74 &.66 &.64 &.65 &.65 &.80 \\
# CDMI & {\cellcolor[HTML]{A5CFA9}}.81 & {\cellcolor[HTML]{B8F2BE}}.81 &.72 &.65 &.82 & {\cellcolor[HTML]{B8F2BE}}.80 &.63 & {\cellcolor[HTML]{A5CFA9}}.71 & {\cellcolor[HTML]{A5CFA9}}.80 & {\cellcolor[HTML]{A5CFA9}}.78 &.75 \\
# CP (Transf) &.60 &.65 &.62 &.68 &.80 &.72 &.56 &.56 &.60 &.65 & \textdagger \\
# CP (Gru) &.66 &.58 &.68 &.56 &.81 &.65 &.56 &.56 &.64 &.60 & \textdagger \\
# \end{tabular}

# %%
build_exp1(scoring="Max individual F1", null_name="Null F1")
# Out:
# renaming.. resolution_value
# renaming.. method_hps.max_lag
# renaming.. method_hps.cp_architecture
# renaming.. ds_name
# renaming.. normalize
# renaming.. window_data_month_value
# renaming.. window_data_year_value
# \begin{tabular}{lrrrrrrrrrrr}
#  & close_3 & close_5 & root_cause_3 & root_cause_5 & 1_random_3 & 1_random_5 & confounder_3 & confounder_5 & random_3 & random_5 & disjoint_10 \\
# Null model &.50 &.34 &.50 &.33 &.29 &.26 &.54 &.36 &.50 &.33 &.16 \\
# RP &.75 &.53 &.71 &.48 &.48 &.42 &.66 &.48 &.74 &.52 &.29 \\
# RP+N &.68 &.46 & {\cellcolor[HTML]{B8F2BE}}.86 & {\cellcolor[HTML]{B8F2BE}}.67 &.55 &.43 &.55 &.45 &.69 &.49 &.36 \\
# RP+B &.73 &.57 &.50 &.33 &.61 &.50 &.56 &.47 &.71 &.53 &.24 \\
# CC &.65 &.44 &.66 &.46 &.44 &.39 &.65 &.43 &.67 &.49 &.25 \\
# CC+C &.67 &.49 &.70 &.57 &.52 &.46 &.60 &.45 &.68 &.52 & {\cellcolor[HTML]{A5CFA9}}.53 \\
# RPCC &.66 &.47 &.64 &.45 &.50 &.42 &.62 &.44 &.67 &.51 &.30 \\
# RPCC+N &.65 &.44 &.73 &.58 &.52 &.43 &.60 &.44 &.67 &.49 &.38 \\
# RPCC+B &.65 &.48 &.55 &.36 &.56 &.44 &.60 &.43 &.65 &.49 &.25 \\
# RPCC+C &.68 &.52 &.68 &.54 &.55 &.47 &.62 &.47 &.68 &.52 & {\cellcolor[HTML]{B8F2BE}}.55 \\
# VAR & {\cellcolor[HTML]{A5CFA9}}.82 & {\cellcolor[HTML]{B8F2BE}}.68 & {\cellcolor[HTML]{A5CFA9}}.80 &.62 &.77 &.60 & {\cellcolor[HTML]{B8F2BE}}.77 & {\cellcolor[HTML]{A5CFA9}}.60 & {\cellcolor[HTML]{B8F2BE}}.83 & {\cellcolor[HTML]{B8F2BE}}.65 &.48 \\
# Varlingam &.81 &.65 &.79 & {\cellcolor[HTML]{A5CFA9}}.64 & {\cellcolor[HTML]{B8F2BE}}.80 & {\cellcolor[HTML]{A5CFA9}}.63 &.72 & {\cellcolor[HTML]{B8F2BE}}.61 &.81 & {\cellcolor[HTML]{A5CFA9}}.63 &.48 \\
# dynotears &.56 &.37 &.60 &.47 &.46 &.49 &.67 &.46 &.62 &.54 &.42 \\
# PCMCI &.68 &.48 &.71 &.57 &.77 &.55 & {\cellcolor[HTML]{A5CFA9}}.73 &.53 &.70 &.52 &.47 \\
# CDMI & {\cellcolor[HTML]{B8F2BE}}.82 & {\cellcolor[HTML]{A5CFA9}}.67 &.73 &.50 & {\cellcolor[HTML]{A5CFA9}}.80 & {\cellcolor[HTML]{B8F2BE}}.63 &.72 &.59 & {\cellcolor[HTML]{A5CFA9}}.82 &.63 &.37 \\
# CP (Transf) &.68 &.53 &.69 &.55 &.77 &.55 &.65 &.49 &.68 &.53 & \textdagger \\
# CP (Gru) &.72 &.48 &.71 &.46 &.78 &.48 &.66 &.49 &.71 &.49 & \textdagger \\
# \end{tabular}
# /tmp/ipykernel_3520831/855385107.py:34: DtypeWarning: Columns (22,24,25,30,54,55,58,59,61,62,63,64,66,67,75,76,77,81,82,85,86,87,88,89,90,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(cfg.data_path + "exp1/cached.csv", index_col=0)

# %%
build_exp1(scoring="Max individual Acc", null_name="Null Acc")
# Out:
# renaming.. resolution_value
# renaming.. method_hps.max_lag
# renaming.. method_hps.cp_architecture
# renaming.. ds_name
# renaming.. normalize
# renaming.. window_data_month_value
# renaming.. window_data_year_value
# \begin{tabular}{lrrrrrrrrrrr}
#  & close_3 & close_5 & root_cause_3 & root_cause_5 & 1_random_3 & 1_random_5 & confounder_3 & confounder_5 & random_3 & random_5 & disjoint_10 \\
# Null model &.67 &.80 &.67 &.80 &.83 &.85 &.63 &.78 &.67 &.80 &.91 \\
# RP &.80 &.80 &.79 &.80 &.83 &.85 &.76 &.78 &.80 &.80 &.91 \\
# RP+N &.78 &.81 & {\cellcolor[HTML]{B8F2BE}}.90 & {\cellcolor[HTML]{B8F2BE}}.89 &.83 &.86 &.67 &.79 &.79 &.82 &.91 \\
# RP+B &.82 &.85 &.67 &.80 &.83 &.87 &.70 &.80 &.80 &.83 &.91 \\
# CC &.76 &.80 &.76 &.80 &.84 &.85 &.74 &.78 &.77 &.81 &.91 \\
# CC+C &.78 &.83 &.80 &.85 &.84 &.86 &.72 &.80 &.79 &.83 &.92 \\
# RPCC &.77 &.81 &.75 &.80 &.85 &.85 &.75 &.79 &.77 &.81 &.91 \\
# RPCC+N &.77 &.82 &.82 &.86 &.85 &.86 &.73 &.80 &.79 &.83 &.91 \\
# RPCC+B &.77 &.83 &.71 &.81 &.86 &.86 &.74 &.80 &.78 &.83 &.91 \\
# RPCC+C &.80 &.84 &.79 &.85 &.86 &.87 &.76 &.82 &.80 &.84 &.92 \\
# VAR & {\cellcolor[HTML]{B8F2BE}}.87 & {\cellcolor[HTML]{B8F2BE}}.86 & {\cellcolor[HTML]{A5CFA9}}.85 & {\cellcolor[HTML]{A5CFA9}}.87 & {\cellcolor[HTML]{A5CFA9}}.92 & {\cellcolor[HTML]{A5CFA9}}.89 & {\cellcolor[HTML]{A5CFA9}}.81 & {\cellcolor[HTML]{A5CFA9}}.84 & {\cellcolor[HTML]{B8F2BE}}.87 & {\cellcolor[HTML]{B8F2BE}}.85 & {\cellcolor[HTML]{B8F2BE}}.93 \\
# Varlingam & {\cellcolor[HTML]{A5CFA9}}.86 & {\cellcolor[HTML]{A5CFA9}}.86 &.85 &.86 & {\cellcolor[HTML]{B8F2BE}}.93 & {\cellcolor[HTML]{B8F2BE}}.89 & {\cellcolor[HTML]{B8F2BE}}.81 & {\cellcolor[HTML]{B8F2BE}}.84 & {\cellcolor[HTML]{A5CFA9}}.86 & {\cellcolor[HTML]{A5CFA9}}.85 &.92 \\
# dynotears &.71 &.81 &.75 &.83 &.87 &.88 &.74 &.81 &.75 &.85 & {\cellcolor[HTML]{A5CFA9}}.93 \\
# PCMCI &.71 &.80 &.78 &.83 &.92 &.87 &.80 &.81 &.77 &.83 &.91 \\
# CDMI &.83 &.84 &.78 &.81 &.91 &.87 &.78 &.81 &.81 &.82 &.91 \\
# CP (Transf) &.76 &.83 &.79 &.84 &.91 &.88 &.74 &.80 &.77 &.83 & \textdagger \\
# CP (Gru) &.79 &.81 &.80 &.81 &.92 &.87 &.76 &.80 &.79 &.82 & \textdagger \\
# \end{tabular}
# /tmp/ipykernel_3520831/855385107.py:34: DtypeWarning: Columns (22,24,25,30,54,55,58,59,61,62,63,64,66,67,75,76,77,81,82,85,86,87,88,89,90,92,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(cfg.data_path + "exp1/cached.csv", index_col=0)

# %% [markdown]
# ### Unused

# %%
with_ranking = pd.DataFrame(
    out.astype(float).round(2).astype(str).values
    + " ("
    + out.rank(ascending=False).values.astype(int).astype(str)
    + ")",
    columns=out.columns,
    index=out.index,
)
with_ranking.style.background_gradient(cmap="YlGn_r", axis="index", vmin=0.4)

# %%
table = out.rank(ascending=True).style.background_gradient(cmap="YlGn_r", axis="index", vmin=0.4)
table.data = out
table.format(precision=2)
# Out:
# <style type="text/css">
# #T_8cfd0_row0_col0, #T_8cfd0_row12_col8 {
#   background-color: #218242;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col1, #T_8cfd0_row0_col2, #T_8cfd0_row12_col1 {
#   background-color: #208242;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col3, #T_8cfd0_row12_col4 {
#   background-color: #288a47;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col4 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col5, #T_8cfd0_row0_col9, #T_8cfd0_row12_col0, #T_8cfd0_row12_col2 {
#   background-color: #228343;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col6 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col7 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col8 {
#   background-color: #1f8142;
#   color: #f1f1f1;
# }
# #T_8cfd0_row0_col10 {
#   background-color: #1e8041;
#   color: #f1f1f1;
# }
# #T_8cfd0_row1_col0 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_8cfd0_row1_col1, #T_8cfd0_row1_col2 {
#   background-color: #f7fcb9;
#   color: #000000;
# }
# #T_8cfd0_row1_col3, #T_8cfd0_row1_col10, #T_8cfd0_row4_col6 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_8cfd0_row1_col4 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_8cfd0_row1_col5, #T_8cfd0_row9_col10 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_8cfd0_row1_col6, #T_8cfd0_row5_col8 {
#   background-color: #d0ec9f;
#   color: #000000;
# }
# #T_8cfd0_row1_col7 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_8cfd0_row1_col8, #T_8cfd0_row16_col4 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_8cfd0_row1_col9 {
#   background-color: #f7fcbc;
#   color: #000000;
# }
# #T_8cfd0_row2_col0, #T_8cfd0_row5_col2 {
#   background-color: #dff3a8;
#   color: #000000;
# }
# #T_8cfd0_row2_col1 {
#   background-color: #89ce80;
#   color: #000000;
# }
# #T_8cfd0_row2_col2, #T_8cfd0_row10_col0, #T_8cfd0_row10_col6, #T_8cfd0_row10_col7, #T_8cfd0_row10_col8, #T_8cfd0_row10_col9, #T_8cfd0_row11_col3, #T_8cfd0_row11_col4, #T_8cfd0_row11_col10, #T_8cfd0_row14_col0, #T_8cfd0_row14_col1, #T_8cfd0_row14_col5 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_8cfd0_row2_col3 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_8cfd0_row2_col4, #T_8cfd0_row9_col4 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_8cfd0_row2_col5, #T_8cfd0_row5_col7, #T_8cfd0_row6_col1, #T_8cfd0_row6_col7, #T_8cfd0_row8_col9 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_8cfd0_row2_col6, #T_8cfd0_row16_col8 {
#   background-color: #98d486;
#   color: #000000;
# }
# #T_8cfd0_row2_col7, #T_8cfd0_row8_col7 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_8cfd0_row2_col8, #T_8cfd0_row4_col9, #T_8cfd0_row5_col6, #T_8cfd0_row14_col2 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_8cfd0_row2_col9, #T_8cfd0_row13_col8 {
#   background-color: #a4d98a;
#   color: #000000;
# }
# #T_8cfd0_row2_col10 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_8cfd0_row3_col0, #T_8cfd0_row11_col8 {
#   background-color: #fafdc8;
#   color: #000000;
# }
# #T_8cfd0_row3_col1, #T_8cfd0_row6_col0, #T_8cfd0_row9_col0, #T_8cfd0_row13_col7 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_8cfd0_row3_col2 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_8cfd0_row3_col3 {
#   background-color: #3aa257;
#   color: #f1f1f1;
# }
# #T_8cfd0_row3_col4, #T_8cfd0_row15_col4 {
#   background-color: #fafdc9;
#   color: #000000;
# }
# #T_8cfd0_row3_col5, #T_8cfd0_row15_col5 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_8cfd0_row3_col6, #T_8cfd0_row5_col4 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_8cfd0_row3_col7 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_8cfd0_row3_col8 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_8cfd0_row3_col9, #T_8cfd0_row7_col6 {
#   background-color: #c9e99c;
#   color: #000000;
# }
# #T_8cfd0_row3_col10 {
#   background-color: #53b466;
#   color: #f1f1f1;
# }
# #T_8cfd0_row4_col0 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_8cfd0_row4_col1 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_8cfd0_row4_col2 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_8cfd0_row4_col3 {
#   background-color: #d2eda0;
#   color: #000000;
# }
# #T_8cfd0_row4_col4 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_8cfd0_row4_col5 {
#   background-color: #b3e091;
#   color: #000000;
# }
# #T_8cfd0_row4_col7 {
#   background-color: #a2d88a;
#   color: #000000;
# }
# #T_8cfd0_row4_col8 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_8cfd0_row4_col10 {
#   background-color: #a7db8c;
#   color: #000000;
# }
# #T_8cfd0_row5_col0 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_8cfd0_row5_col1, #T_8cfd0_row13_col0 {
#   background-color: #9cd687;
#   color: #000000;
# }
# #T_8cfd0_row5_col3, #T_8cfd0_row7_col3 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_8cfd0_row5_col5, #T_8cfd0_row14_col3 {
#   background-color: #bee596;
#   color: #000000;
# }
# #T_8cfd0_row5_col9, #T_8cfd0_row6_col3, #T_8cfd0_row7_col0, #T_8cfd0_row8_col0, #T_8cfd0_row9_col9, #T_8cfd0_row16_col2 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_8cfd0_row5_col10, #T_8cfd0_row14_col10 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_8cfd0_row6_col2, #T_8cfd0_row6_col10, #T_8cfd0_row13_col2 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_8cfd0_row6_col4, #T_8cfd0_row13_col9, #T_8cfd0_row16_col0 {
#   background-color: #afde8f;
#   color: #000000;
# }
# #T_8cfd0_row6_col5 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_8cfd0_row6_col6, #T_8cfd0_row8_col6, #T_8cfd0_row14_col6 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_8cfd0_row6_col8 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_8cfd0_row6_col9 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_8cfd0_row7_col1, #T_8cfd0_row8_col2 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_8cfd0_row7_col2 {
#   background-color: #e6f5ac;
#   color: #000000;
# }
# #T_8cfd0_row7_col4, #T_8cfd0_row16_col5 {
#   background-color: #a9db8c;
#   color: #000000;
# }
# #T_8cfd0_row7_col5 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_8cfd0_row7_col7 {
#   background-color: #86cc7f;
#   color: #000000;
# }
# #T_8cfd0_row7_col8 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_8cfd0_row7_col9, #T_8cfd0_row7_col10, #T_8cfd0_row15_col1 {
#   background-color: #a6da8b;
#   color: #000000;
# }
# #T_8cfd0_row8_col1 {
#   background-color: #92d183;
#   color: #000000;
# }
# #T_8cfd0_row8_col3 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_8cfd0_row8_col4 {
#   background-color: #cfec9e;
#   color: #000000;
# }
# #T_8cfd0_row8_col5 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_8cfd0_row8_col8 {
#   background-color: #c3e698;
#   color: #000000;
# }
# #T_8cfd0_row8_col10, #T_8cfd0_row12_col6 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_8cfd0_row9_col1 {
#   background-color: #abdc8d;
#   color: #000000;
# }
# #T_8cfd0_row9_col2, #T_8cfd0_row9_col8 {
#   background-color: #d6efa2;
#   color: #000000;
# }
# #T_8cfd0_row9_col3, #T_8cfd0_row15_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_8cfd0_row9_col5 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_8cfd0_row9_col6 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_8cfd0_row9_col7 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_8cfd0_row10_col1, #T_8cfd0_row10_col10 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_8cfd0_row10_col2, #T_8cfd0_row13_col10 {
#   background-color: #fbfed0;
#   color: #000000;
# }
# #T_8cfd0_row10_col3, #T_8cfd0_row14_col4, #T_8cfd0_row14_col9 {
#   background-color: #fcfed4;
#   color: #000000;
# }
# #T_8cfd0_row10_col4 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_8cfd0_row10_col5, #T_8cfd0_row13_col4 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_8cfd0_row11_col0, #T_8cfd0_row14_col8 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_8cfd0_row11_col1, #T_8cfd0_row11_col2 {
#   background-color: #f9fdc2;
#   color: #000000;
# }
# #T_8cfd0_row11_col5 {
#   background-color: #fdfeda;
#   color: #000000;
# }
# #T_8cfd0_row11_col6 {
#   background-color: #f8fcc0;
#   color: #000000;
# }
# #T_8cfd0_row11_col7 {
#   background-color: #fafdcb;
#   color: #000000;
# }
# #T_8cfd0_row11_col9 {
#   background-color: #f8fcbd;
#   color: #000000;
# }
# #T_8cfd0_row12_col3 {
#   background-color: #5fba6c;
#   color: #f1f1f1;
# }
# #T_8cfd

# %% [markdown]
# ## Check HPS

# %%
data = pd.read_csv("grid_export_exp1/" + "var_" + ".csv", index_col=0)
data[data["label_path"].str.contains("random_3")].sort_values("Individual AUROC").iloc[-1]
# Out:
# Max Acc thresh                              0.380419
# Max Acc                                     0.777174
# Max individual Acc thresh                   0.307312
# Max individual Acc                          0.870401
# Null Acc                                     0.66597
# Max F1 thresh                             149.058716
# Max F1                                      0.691409
# Max individual F1 thresh                    2.526716
# Max individual F1                           0.827809
# Null F1                                     0.500783
# AUROC                                       0.815445
# Individual AUROC                             0.82323
# Null AUROC                                       0.5
# runtime                       0 days 00:00:45.491594
# data_preprocess.resolution                        6H
# data_preprocess.normalize                      False
# label_path                                  random_3
# method.max_lag                                     5
# method.var_absolute_values                     False
# method.filter_mode                               NaN
# Name: 2024-10-16 10:03:18.4064, dtype: object
