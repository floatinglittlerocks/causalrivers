# %%
import pandas as pd
from IPython.display import display, HTML
import numpy as np
from hydra import initialize, compose

from assembly_tools import load_experimental_grid, format_table, extract_raw_performance

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Assembly of experimental results 2

# %%
# load default params. They can be changed however you want.
with initialize(version_base=None, config_path="config"):
    cfg = compose(config_name='extract.yaml')
    print(cfg)
general_params =  ["resolution_value", "ds_name", "method_hps.max_lag"]
hp_stack = []
performance_stack = []
scoring = 'Individual AUROC'
cfg.ds_order = ["random_5"]
# Out:
# {'metrics': ['Max Acc thresh', 'Max Acc', 'Max individual Acc thresh', 'Max individual Acc', 'Null Acc', 'Max F1 thresh', 'Max F1', 'Max individual F1 thresh', 'Max individual F1', 'Null F1', 'AUROC', 'Individual AUROC', 'Null AUROC', 'runtime'], 'hp_list': ['data_preprocess.resolution', 'data_preprocess.normalize', 'label_path', 'method.max_lag', 'method.var_absolute_values', 'method.filter_mode', 'method.architecture'], 'rename': {'resolution_value': 'data_preprocess.resolution', 'method_hps.var_absolute_values': 'method.var_absolute_values', 'method_hps.filter_mode': 'method.filter_mode', 'method_hps.max_lag': 'method.max_lag', 'method_hps.cp_architecture': 'method.architecture', 'ds_name': 'label_path', 'normalize': 'data_preprocess.normalize', 'window_data_month_value': 'data_preprocess.subset_month', 'window_data_year_value': 'data_preprocess.subset_year'}, 'ds_order': ['close_3', 'close_5', 'root_cause_3', 'root_cause_5', '1_random_3', '1_random_5', 'confounder_3', 'confounder_5', 'random_3', 'random_5', 'disjoint_10'], 'data_path': '/home/datasets4/stein/rivers/paper_result_storage/new_runs/', 'exp': 'exp1/', 'method_name': 'combo', 'save_path': 'grid_export_'}

# %%
for name in ["reverse", "cross", "combo", "var_", "varlingam","pcmci","dyno","cp"]:
    data = pd.read_csv("grid_export_exp2/" + name + ".csv", index_col=0)
    res = ["data_path",  "data_preprocess.subset_year"]
    formatted = format_table(data,cfg, scoring= scoring, restriction=res)
    lines = extract_raw_performance(formatted,cfg,scoring,name="", restriction=res)
    lines.columns = [name]
    hp_stack.append(formatted)
    performance_stack.append(lines)
# Out:
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')
# Fail: ('resources/rivers_flood.csv', '2021', 'random_5')

# %%
# We ran this completely distributed so we load the raw files here.
data = load_experimental_grid(mypath=cfg.data_path + "exp2/", method_name="cdmi").T

# %%
out = pd.concat(performance_stack,axis=1).T

# %%
out
# Out:
#           _resources/rivers_ts_east_germany.csv-2021  \
# reverse                                     0.777964
# cross                                       0.739024
# combo                                       0.792449
# var_                                        0.864876
# varlingam                                   0.666344
# pcmci                                       0.686058
# dyno                                        0.600205
# cp                                          0.662733
#
#           _resources/rivers_ts_east_germany.csv-False  \
# reverse                                      0.778694
# cross                                        0.807126
# combo                                        0.807413
# var_                                          0.84931
# varlingam                                    0.722566
# pcmci                                        0.605406
# dyno                                         0.788594
# cp                                           0.649147
#
#           _resources/rivers_flood.csv-False
# reverse                            0.700476
# cross                              0.802394
# combo                              0.745151
# var_                               0.834518
# varlingam                          0.738455
# pcmci                              0.595912
# dyno                               0.800946
# cp                                 0.744968

# %%
out = out[[out.columns[1], out.columns[0], out.columns[2]]]
out.columns = ["Full TS", "No Rain", "Flood"]
out.loc["cdmi"] = [data["Individual AUROC"].mean(), np.nan, np.nan]
out.index = ["RP", "CC", "RPCC", "VAR", "Varlingam", "PCMCI", "Dynotears", "CP", "CDMI"]
out = out.astype(float).round(3)
# Out:
# /tmp/ipykernel_2350123/3971062343.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   out.loc["cdmi"] = [data["Individual AUROC"].mean(), np.nan, np.nan]

# %%
# switch order
out =out.loc[list(out.index[:-2]) + ["CDMI"] + ["CP"]]

# %%
style = out.style.highlight_max(axis=1,  props='color:black;font-weight:bold')
style = style.format("{:.2f}")
latex_str = style.to_latex(convert_css=True)
display(HTML(style.to_html()))
print(latex_str.replace("nan", "\\textdagger"))
# Out:
# <style type="text/css">
# #T_4fb69_row0_col0, #T_4fb69_row1_col0, #T_4fb69_row2_col0, #T_4fb69_row3_col1, #T_4fb69_row4_col2, #T_4fb69_row5_col1, #T_4fb69_row6_col2, #T_4fb69_row7_col0, #T_4fb69_row8_col2 {
#   color: black;
#   font-weight: bold;
# }
# </style>
# <table id="T_4fb69">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4fb69_level0_col0" class="col_heading level0 col0" >Full TS</th>
#       <th id="T_4fb69_level0_col1" class="col_heading level0 col1" >No Rain</th>
#       <th id="T_4fb69_level0_col2" class="col_heading level0 col2" >Flood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4fb69_level0_row0" class="row_heading level0 row0" >RP</th>
#       <td id="T_4fb69_row0_col0" class="data row0 col0" >0.78</td>
#       <td id="T_4fb69_row0_col1" class="data row0 col1" >0.78</td>
#       <td id="T_4fb69_row0_col2" class="data row0 col2" >0.70</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row1" class="row_heading level0 row1" >CC</th>
#       <td id="T_4fb69_row1_col0" class="data row1 col0" >0.81</td>
#       <td id="T_4fb69_row1_col1" class="data row1 col1" >0.74</td>
#       <td id="T_4fb69_row1_col2" class="data row1 col2" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row2" class="row_heading level0 row2" >RPCC</th>
#       <td id="T_4fb69_row2_col0" class="data row2 col0" >0.81</td>
#       <td id="T_4fb69_row2_col1" class="data row2 col1" >0.79</td>
#       <td id="T_4fb69_row2_col2" class="data row2 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row3" class="row_heading level0 row3" >VAR</th>
#       <td id="T_4fb69_row3_col0" class="data row3 col0" >0.85</td>
#       <td id="T_4fb69_row3_col1" class="data row3 col1" >0.86</td>
#       <td id="T_4fb69_row3_col2" class="data row3 col2" >0.83</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row4" class="row_heading level0 row4" >Varlingam</th>
#       <td id="T_4fb69_row4_col0" class="data row4 col0" >0.72</td>
#       <td id="T_4fb69_row4_col1" class="data row4 col1" >0.67</td>
#       <td id="T_4fb69_row4_col2" class="data row4 col2" >0.74</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row5" class="row_heading level0 row5" >PCMCI</th>
#       <td id="T_4fb69_row5_col0" class="data row5 col0" >0.60</td>
#       <td id="T_4fb69_row5_col1" class="data row5 col1" >0.69</td>
#       <td id="T_4fb69_row5_col2" class="data row5 col2" >0.60</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row6" class="row_heading level0 row6" >Dynotears</th>
#       <td id="T_4fb69_row6_col0" class="data row6 col0" >0.79</td>
#       <td id="T_4fb69_row6_col1" class="data row6 col1" >0.60</td>
#       <td id="T_4fb69_row6_col2" class="data row6 col2" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row7" class="row_heading level0 row7" >CDMI</th>
#       <td id="T_4fb69_row7_col0" class="data row7 col0" >0.83</td>
#       <td id="T_4fb69_row7_col1" class="data row7 col1" >nan</td>
#       <td id="T_4fb69_row7_col2" class="data row7 col2" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_4fb69_level0_row8" class="row_heading level0 row8" >CP</th>
#       <td id="T_4fb69_row8_col0" class="data row8 col0" >0.65</td>
#       <td id="T_4fb69_row8_col1" class="data row8 col1" >0.66</td>
#       <td id="T_4fb69_row8_col2" class="data row8 col2" >0.74</td>
#     </tr>
#   </tbody>
# </table>
# \begin{tabular}{lrrr}
#  & Full TS & No Rain & Flood \\
# RP & \color{black} \bfseries 0.78 & 0.78 & 0.70 \\
# CC & \color{black} \bfseries 0.81 & 0.74 & 0.80 \\
# RPCC & \color{black} \bfseries 0.81 & 0.79 & 0.74 \\
# VAR & 0.85 & \color{black} \bfseries 0.86 & 0.83 \\
# Varlingam & 0.72 & 0.67 & \color{black} \bfseries 0.74 \\
# PCMCI & 0.60 & \color{black} \bfseries 0.69 & 0.60 \\
# Dynotears & 0.79 & 0.60 & \color{black} \bfseries 0.80 \\
# CDMI & \color{black} \bfseries 0.83 & \textdagger & \textdagger \\
# CP & 0.65 & 0.66 & \color{black} \bfseries 0.74 \\
# \end{tabular}

# %% [markdown]
# ### CHeck HPS for control

# %%
data = pd.read_csv("grid_export_exp2/" + "dyno" + ".csv", index_col=0)

# %%
data.sort_values("Individual AUROC").T
# Out:
#                                           2024-11-25 11:13:48.4063  \
# Max Acc thresh                                            0.080387
# Max Acc                                                   0.829547
# Max individual Acc thresh                                 0.047547
# Max individual Acc                                        0.841117
# Null Acc                                                  0.799813
# Max F1 thresh                                             0.393657
# Max F1                                                    0.345661
# Max individual F1 thresh                                  0.111812
# Max individual F1                                          0.43036
# Null F1                                                   0.333593
# AUROC                                                     0.464082
# Individual AUROC                                           0.47926
# Null AUROC                                                     0.5
# runtime                                     0 days 00:15:23.984480
# data_preprocess.resolution                                      1H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                   2021
# data_preprocess.subset_month                                    10
#
#                                           2024-11-25 11:41:58.4038  \
# Max Acc thresh                                            1.436211
# Max Acc                                                   0.828448
# Max individual Acc thresh                                 0.542428
# Max individual Acc                                        0.839925
# Null Acc                                                  0.799813
# Max F1 thresh                                             0.039287
# Max F1                                                    0.364962
# Max individual F1 thresh                                   1.39183
# Max individual F1                                         0.444082
# Null F1                                                   0.333593
# AUROC                                                     0.497075
# Individual AUROC                                          0.494852
# Null AUROC                                                     0.5
# runtime                                     0 days 00:36:17.471737
# data_preprocess.resolution                                     24H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                   2021
# data_preprocess.subset_month                                    10
#
#                                           2024-11-22 03:40:24.0442  \
# Max Acc thresh                                                0.01
# Max Acc                                                   0.799813
# Max individual Acc thresh                                 0.000005
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                             0.008239
# Max F1                                                    0.333593
# Max individual F1 thresh                                  0.000004
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                     0.499985
# Individual AUROC                                          0.499985
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:23.959195
# data_preprocess.resolution                                     24H
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-22 03:31:24.1167  \
# Max Acc thresh                                                0.01
# Max Acc                                                   0.799813
# Max individual Acc thresh                                 0.000005
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                             0.002033
# Max F1                                                    0.333593
# Max individual F1 thresh                                  0.000001
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                     0.499985
# Individual AUROC                                          0.499985
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:21.593012
# data_preprocess.resolution                                     24H
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   3
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 18:30:42.0919  \
# Max Acc thresh                                                 0.0
# Max Acc                                                   0.799813
# Max individual Acc thresh                                      0.0
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                                  0.0
# Max F1                                                    0.333593
# Max individual F1 thresh                                       0.0
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                          0.5
# Individual AUROC                                               0.5
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:27.641552
# data_preprocess.resolution                                      6H
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 22:39:50.7143  \
# Max Acc thresh                                                 0.0
# Max Acc                                                   0.799813
# Max individual Acc thresh                                      0.0
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                                  0.0
# Max F1                                                    0.333593
# Max individual F1 thresh                                       0.0
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                          0.5
# Individual AUROC                                               0.5
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:30.897498
# data_preprocess.resolution                                     12H
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 14:54:13.4228  \
# Max Acc thresh                                                 0.0
# Max Acc                                                   0.799813
# Max individual Acc thresh                                      0.0
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                                  0.0
# Max F1                                                    0.333593
# Max individual F1 thresh                                       0.0
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                          0.5
# Individual AUROC                                               0.5
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:52.290666
# data_preprocess.resolution                                   15min
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   3
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 14:59:36.9196  \
# Max Acc thresh                                                 0.0
# Max Acc                                                   0.799813
# Max individual Acc thresh                                      0.0
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                                  0.0
# Max F1                                                    0.333593
# Max individual F1 thresh                                       0.0
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                          0.5
# Individual AUROC                                               0.5
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:54.464687
# data_preprocess.resolution                                   15min
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 16:13:31.7504  \
# Max Acc thresh                                                 0.0
# Max Acc                                                   0.799813
# Max individual Acc thresh                                      0.0
# Max individual Acc                                        0.799813
# Null Acc                                                  0.799813
# Max F1 thresh                                                  0.0
# Max F1                                                    0.333593
# Max individual F1 thresh                                       0.0
# Max individual F1                                         0.333583
# Null F1                                                   0.333593
# AUROC                                                          0.5
# Individual AUROC                                               0.5
# Null AUROC                                                     0.5
# runtime                                     0 days 00:00:32.124784
# data_preprocess.resolution                                      1H
# data_preprocess.normalize                                     True
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-21 16:10:57.9372  ...  \
# Max Acc thresh                                                 0.0  ...
# Max Acc                                                   0.799813  ...
# Max individual Acc thresh                                      0.0  ...
# Max individual Acc                                        0.799813  ...
# Null Acc                                                  0.799813  ...
# Max F1 thresh                                                  0.0  ...
# Max F1                                                    0.333593  ...
# Max individual F1 thresh                                       0.0  ...
# Max individual F1                                         0.333583  ...
# Null F1                                                   0.333593  ...
# AUROC                                                          0.5  ...
# Individual AUROC                                               0.5  ...
# Null AUROC                                                     0.5  ...
# runtime                                     0 days 00:00:29.937425  ...
# data_preprocess.resolution                                      1H  ...
# data_preprocess.normalize                                     True  ...
# label_path                                                random_5  ...
# method.max_lag                                                   3  ...
# method.filter_mode                                             NaN  ...
# method.architecture                                    transformer  ...
# data_path                     resources/rivers_ts_east_germany.csv  ...
# data_preprocess.subset_year                                  False  ...
# data_preprocess.subset_month                                    []  ...
#
#                                 2024-11-21 22:32:11.9597  \
# Max Acc thresh                                  0.551249
# Max Acc                                         0.832772
# Max individual Acc thresh                       0.355114
# Max individual Acc                              0.871879
# Null Acc                                        0.799813
# Max F1 thresh                                   4.931537
# Max F1                                          0.537572
# Max individual F1 thresh                        0.594957
# Max individual F1                               0.670298
# Null F1                                         0.333593
# AUROC                                           0.729061
# Individual AUROC                                0.749906
# Null AUROC                                           0.5
# runtime                           0 days 02:05:34.697871
# data_preprocess.resolution                            6H
# data_preprocess.normalize                          False
# label_path                                      random_5
# method.max_lag                                         5
# method.filter_mode                                   NaN
# method.architecture                          transformer
# data_path                     resources/rivers_flood.csv
# data_preprocess.subset_year                        False
# data_preprocess.subset_month                          []
#
#                                           2024-11-22 07:28:08.2394  \
# Max Acc thresh                                            2.284761
# Max Acc                                                   0.807667
# Max individual Acc thresh                                 1.302548
# Max individual Acc                                        0.861688
# Null Acc                                                  0.799813
# Max F1 thresh                                            46.316821
# Max F1                                                    0.608891
# Max individual F1 thresh                                   2.91327
# Max individual F1                                         0.665818
# Null F1                                                   0.333593
# AUROC                                                     0.761011
# Individual AUROC                                          0.756396
# Null AUROC                                                     0.5
# runtime                                     0 days 02:50:21.700172
# data_preprocess.resolution                                     24H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   3
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-22 01:46:37.7685  \
# Max Acc thresh                                            0.269504
# Max Acc                                                   0.839271
# Max individual Acc thresh                                 0.167617
# Max individual Acc                                        0.879547
# Null Acc                                                  0.799813
# Max F1 thresh                                             4.638699
# Max F1                                                    0.556714
# Max individual F1 thresh                                   0.31061
# Max individual F1                                         0.678669
# Null F1                                                   0.333593
# AUROC                                                     0.747971
# Individual AUROC                                          0.757733
# Null AUROC                                                     0.5
# runtime                                     0 days 06:12:05.634115
# data_preprocess.resolution                                      6H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   3
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                           2024-11-22 05:29:02.2997  \
# Max Acc thresh                                            0.509112
# Max Acc                                                   0.826928
# Max individual Acc thresh                                 0.527261
# Max individual Acc                                        0.867882
# Null Acc                                                  0.799813
# Max F1 thresh                                            33.317007
# Max F1                                                    0.603899
# Max individual F1 thresh                                   1.25741
# Max individual F1                                         0.678558
# Null F1                                                   0.333593
# AUROC                                                     0.770804
# Individual AUROC                                          0.767717
# Null AUROC                                                     0.5
# runtime                                     0 days 06:45:40.995835
# data_preprocess.resolution                                     12H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   3
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                 2024-11-22 15:17:11.7679  \
# Max Acc thresh                                  2.350295
# Max Acc                                         0.829266
# Max individual Acc thresh                       2.879277
# Max individual Acc                              0.870173
# Null Acc                                        0.799813
# Max F1 thresh                                   0.290243
# Max F1                                          0.582567
# Max individual F1 thresh                        10.82367
# Max individual F1                               0.678106
# Null F1                                         0.333593
# AUROC                                           0.789445
# Individual AUROC                                 0.77575
# Null AUROC                                           0.5
# runtime                           0 days 09:48:03.248603
# data_preprocess.resolution                           24H
# data_preprocess.normalize                          False
# label_path                                      random_5
# method.max_lag                                         5
# method.filter_mode                                   NaN
# method.architecture                          transformer
# data_path                     resources/rivers_flood.csv
# data_preprocess.subset_year                        False
# data_preprocess.subset_month                          []
#
#                                           2024-11-22 12:11:38.5502  \
# Max Acc thresh                                            0.261412
# Max Acc                                                   0.815965
# Max individual Acc thresh                                  1.13746
# Max individual Acc                                        0.865404
# Null Acc                                                  0.799813
# Max F1 thresh                                            41.159719
# Max F1                                                    0.617644
# Max individual F1 thresh                                  2.922392
# Max individual F1                                         0.686847
# Null F1                                                   0.333593
# AUROC                                                     0.784938
# Individual AUROC                                          0.782386
# Null AUROC                                                     0.5
# runtime                                     0 days 04:43:23.019742
# data_preprocess.resolution                                     24H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                 2024-11-22 10:22:59.4068  \
# Max Acc thresh                                  1.955577
# Max Acc                                         0.832328
# Max individual Acc thresh                       3.053819
# Max individual Acc                              0.872978
# Null Acc                                        0.799813
# Max F1 thresh                                   0.510695
# Max F1                                          0.622152
# Max individual F1 thresh                       14.142205
# Max individual F1                               0.698018
# Null F1                                         0.333593
# AUROC                                           0.803423
# Individual AUROC                                0.788372
# Null AUROC                                           0.5
# runtime                           0 days 06:42:30.707121
# data_preprocess.resolution                           24H
# data_preprocess.normalize                          False
# label_path                                      random_5
# method.max_lag                                         3
# method.filter_mode                                   NaN
# method.architecture                          transformer
# data_path                     resources/rivers_flood.csv
# data_preprocess.subset_year                        False
# data_preprocess.subset_month                          []
#
#                                           2024-11-22 10:01:50.8508  \
# Max Acc thresh                                             0.56047
# Max Acc                                                   0.833614
# Max individual Acc thresh                                 0.509121
# Max individual Acc                                         0.87244
# Null Acc                                                  0.799813
# Max F1 thresh                                             21.99817
# Max F1                                                    0.607836
# Max individual F1 thresh                                  1.110293
# Max individual F1                                         0.691835
# Null F1                                                   0.333593
# AUROC                                                     0.790937
# Individual AUROC                                          0.788594
# Null AUROC                                                     0.5
# runtime                                     0 days 07:31:17.344939
# data_preprocess.resolution                                     12H
# data_preprocess.normalize                                    False
# label_path                                                random_5
# method.max_lag                                                   5
# method.filter_mode                                             NaN
# method.architecture                                    transformer
# data_path                     resources/rivers_ts_east_germany.csv
# data_preprocess.subset_year                                  False
# data_preprocess.subset_month                                    []
#
#                                 2024-11-22 08:00:25.3036  \
# Max Acc thresh                                  1.315258
# Max Acc                                         0.838663
# Max individual Acc thresh                        0.90532
# Max individual Acc                              0.877326
# Null Acc                                        0.799813
# Max F1 thresh                                   0.470034
# Max F1                                          0.589704
# Max individual F1 thresh                        2.029269
# Max individual F1                               0.697545
# Null F1                                         0.333593
# AUROC                                           0.797635
# Individual AUROC                                0.797392
# Null AUROC                                           0.5
# runtime                           0 days 06:13:39.752489
# data_preprocess.resolution                           12H
# data_preprocess.normalize                          False
# label_path                                      random_5
# method.max_lag                                         5
# method.filter_mode                                   NaN
# method.architecture                          transformer
# data_path                     resources/rivers_flood.csv
# data_preprocess.subset_year                        False
# data_preprocess.subset_month                          []
#
#                                 2024-11-22 02:30:26.0550
# Max Acc thresh                                  1.267393
# Max Acc                                         0.837775
# Max individual Acc thresh                       0.892005
# Max individual Acc                              0.877443
# Null Acc                                        0.799813
# Max F1 thresh                                   0.328386
# Max F1                                          0.609715
# Max individual F1 thresh                        2.285125
# Max individual F1                               0.707216
# Null F1                                         0.333593
# AUROC                                           0.798929
# Individual AUROC                                0.800946
# Null AUROC                                           0.5
# runtime                           0 days 03:50:30.398543
# data_preprocess.resolution                           12H
# data_preprocess.normalize                          False
# label_path                                      random_5
# method.max_lag                                         3
# method.filter_mode                                   NaN
# method.architecture                          transformer
# data_path                     resources/rivers_flood.csv
# data_preprocess.subset_year                        False
# data_preprocess.subset_month                          []
#
# [23 rows x 60 columns]
